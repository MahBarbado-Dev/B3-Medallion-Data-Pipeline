# %%
import pandas as pd 
from scripts.parser_cotahist import ler_cotahist

df = ler_cotahist("dados_brutos/COTAHIST_A2024.TXT", nrows=100)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from scripts.parser_cotahist import ler_cotahist
#       3 df = ler_cotahist("dados_brutos/COTAHIST_A2024.TXT", nrows=100)
#       4 df.head()
#
# ModuleNotFoundError: No module named 'scripts'
